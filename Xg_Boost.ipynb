# %%
import pandas as pd
merged_df = pd.read_csv('Merged_DatasetV2.csv')
merged_df.head()
# Out:
#    Unnamed: 0                                    id                type  \
# 0           0  f9a1fd95-4c6d-43a6-bb31-4ee8d5a44a8b              Studio
# 1           1  42e9fa7c-a981-44f9-943c-bf39a8c6ce8d               Venue
# 2           2  34e7351d-715d-4b20-a5d6-3c0bd717eb1d  Religious building
# 3           3  0ad32768-514b-410f-9d5a-40ebb0c3373c              Studio
# 4           4  0b050655-48da-4be7-b5de-7a3ee7370b9e               Venue
#
#                                          name                      city  \
# 0                   Columbia (CBS) Studio ‘B’           Test Restaurant
# 1                          New Theatre Oxford      Victoria House Hotel
# 2  Santuario della Beata Vergine di Ariadello                 Genivolta
# 3                                     ROKU-st               Tenso Jinja
# 4                               Rätschenmühle  Geislingen an der Steige
#
#       state       county country  lifespan_years  status services_offered
# 0  New York          NaN      US             NaN  Active              NaN
# 1   England  Oxfordshire      GB             NaN  Active              NaN
# 2       NaN          NaN      IT           359.0  Active              NaN
# 3       NaN          NaN      JP             NaN  Active              NaN
# 4       NaN          NaN      DE             NaN  Active              NaN

# %%
# Drop rows where 'services_offered' is null
merged_df = merged_df.dropna(subset=['services_offered'])

# Drop the specified columns
merged_df = merged_df.drop(columns=['Unnamed: 0', 'id', 'name'])

# Display the updated dataframe
merged_df.head()
# Out:
#          type                                 city             state  \
# 15520   Other                          Los Jarales               NaN
# 15521   Venue                               Plasky  Brussels Capital
# 15522   Other                       Dunluce Castle  Northern Ireland
# 15524  Studio  Saint Johns Eastern Orthodox Church         Tennessee
# 15525   Venue                    Shimokitazawa Eki               NaN
#
#                          county country  lifespan_years  status  \
# 15520                       NaN      VE             NaN  Active
# 15521        Bruxelles-Capitale      BE            62.0  Active
# 15522  Causeway Coast and Glens      GB             NaN  Active
# 15524                       NaN      US             5.0   Ended
# 15525                       NaN      JP            34.0  Active
#
#       services_offered
# 15520      recorded at
# 15521      recorded at
# 15522      recorded at
# 15524    engineered at
# 15525      recorded at

# %%
# Ensure the column is string type and split by commas (handling spaces)
merged_df['services_offered'] = merged_df['services_offered'].astype(str).str.split(r',\s*')

# Explode the dataframe to have one service per row
merged_df = merged_df.explode('services_offered')

# Trim any leading or trailing spaces (just in case)
merged_df['services_offered'] = merged_df['services_offered'].str.strip()

# Drop any empty values that might have been created
merged_df = merged_df[merged_df['services_offered'].notna() & (merged_df['services_offered'] != '')]

# Reset index after exploding
merged_df = merged_df.reset_index(drop=True)

# %%
import re

# Function to remove the last word and underscore
def remove_last_part(text):
    return re.sub(r'_[^_]+$', '', text)  # Removes the last underscore and the word after it

# Apply the function to the column
merged_df['services_offered'] = merged_df['services_offered'].astype(str).apply(remove_last_part)

# Display the cleaned column
print(merged_df['services_offered'].unique())
# Out:
# ['recorded at' 'engineered at' 'edited at' 'mixed at' 'video shot at'
#  'lyrics written at' 'produced at' 'premiere' 'written at' 'commissioned'
#  'composed at' 'arranged at' 'dedication' 'revised at' 'remixed at']

# %%
def impute_df(df):
    # Fill non-numeric columns with "Missing"
    cols_to_fill = df.columns.difference(['lifespan_years'])
    df[cols_to_fill] = df[cols_to_fill].fillna("Missing")
    
    # Create missing indicator for 'lifespan_years'
    df['lifespan_years_missing'] = df['lifespan_years'].isnull().astype(int)
    
    # Impute missing values in 'lifespan_years' with the median value
    median_val = df['lifespan_years'].median()
    df['lifespan_years'] = df['lifespan_years'].fillna(median_val)
    
    return df

# %%
from sklearn.model_selection import train_test_split


train_df, test_df = train_test_split(merged_df, test_size=0.2, random_state=42)


train_df = impute_df(train_df)
test_df = impute_df(test_df)

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Training set chart
train_counts = train_df['services_offered'].value_counts(normalize=True)
train_counts.plot(kind='bar', ax=axes[0])
axes[0].set_title("Distribution of Services Offered in Training Set")
axes[0].set_xlabel("Services Offered")
axes[0].set_ylabel("Proportion")

# Test set chart
test_counts = test_df['services_offered'].value_counts(normalize=True)
test_counts.plot(kind='bar', ax=axes[1])
axes[1].set_title("Distribution of Services Offered in Test Set")
axes[1].set_xlabel("Services Offered")
axes[1].set_ylabel("Proportion")

plt.tight_layout()
plt.show()

# %%
import xgboost as xgb
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score

# Assume train_df and test_df are already loaded.

# Transform your training data as before.
X_train = pd.get_dummies(train_df.drop(columns=["services_offered", "lifespan_years"]), drop_first=True)
X_train["lifespan_years"] = train_df["lifespan_years"]
X_train.columns = X_train.columns.astype(str).str.replace(r"[,\[\]<>]", "_", regex=True)

# Similarly, transform the test data.
X_test = pd.get_dummies(test_df.drop(columns=["services_offered", "lifespan_years"]), drop_first=True)
X_test["lifespan_years"] = test_df["lifespan_years"]
X_test.columns = X_test.columns.astype(str).str.replace(r"[,\[\]<>]", "_", regex=True)

# Reindex X_test to have the same columns as X_train, filling missing columns with zeros.
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# Encode the target variable.
le = LabelEncoder()
y_train = le.fit_transform(train_df["services_offered"])
y_test = le.fit_transform(test_df["services_offered"])

# Initialize the cross-validation scheme.
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# List to store macro F1 scores for each fold.
f1_list = []

# Manual cross-validation loop.
for fold, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train), 1):
    X_train_fold = X_train.iloc[train_idx]
    y_train_fold = y_train[train_idx]
    X_val_fold = X_train.iloc[val_idx]
    y_val_fold = y_train[val_idx]
    
    # Train the model.
    model = xgb.XGBClassifier(random_state=42)
    model.fit(X_train_fold, y_train_fold)
    
    # Predict on the validation fold.
    preds = model.predict(X_val_fold)
    
    # Calculate macro F1 score.
    f1 = f1_score(y_val_fold, preds, average='macro')
    f1_list.append(f1)
    
    print(f"Fold {fold}: Macro F1 Score={f1:.4f}")

# Compute and print overall cross-validation macro F1 score.
print("\nCross-Validation Results:")
print("Macro F1 Score: Mean =", np.mean(f1_list), ", Std =", np.std(f1_list))

# Train on full training set and evaluate on the test set.
model = xgb.XGBClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Optionally, convert predictions back to original labels.
y_test_labels = le.inverse_transform(y_test)
y_pred_labels = le.inverse_transform(y_pred)
# Out:
# Fold 1: Macro F1 Score=0.0807
# Fold 2: Macro F1 Score=0.0957
# Fold 3: Macro F1 Score=0.0949
# Fold 4: Macro F1 Score=0.0765
# Fold 5: Macro F1 Score=0.0890
#
# Cross-Validation Results:
# Macro F1 Score: Mean = 0.08734789025941532 , Std = 0.007642725334229131

# %%
from sklearn.metrics import classification_report

# Print the classification report across all target classes
print(classification_report(y_test_labels, y_pred_labels))
# Out:
#                    precision    recall  f1-score   support
#
#       arranged at       0.00      0.00      0.00        15
#      commissioned       0.00      0.00      0.00         3
#       composed at       0.00      0.00      0.00        10
#        dedication       0.00      0.00      0.00         1
#         edited at       0.12      0.02      0.03        51
#     engineered at       0.32      0.03      0.06       243
# lyrics written at       0.00      0.00      0.00         2
#          mixed at       0.37      0.11      0.17       659
#          premiere       0.00      0.00      0.00        46
#       produced at       0.00      0.00      0.00        48
#       recorded at       0.70      0.97      0.81      2321
#        remixed at       0.00      0.00      0.00        11
#     video shot at       0.00      0.00      0.00        23
#        written at       0.00      0.00      0.00         9
#
#          accuracy                           0.68      3442
#         macro avg       0.11      0.08      0.08      3442
#      weighted avg       0.57      0.68      0.59      3442

# %%
from sklearn.metrics import classification_report


# Compute classification report as a dictionary
report_dict = classification_report(y_test_labels, y_pred_labels, output_dict=True)

# Convert report to a DataFrame for easier plotting
report_df = pd.DataFrame(report_dict).transpose()

# Remove aggregate scores; we keep only per-class metrics (precision, recall, f1-score)
classes = report_df.drop(index=["accuracy", "macro avg", "weighted avg"])

# Plot grouped bar chart
classes[['precision', 'recall', 'f1-score']].plot(kind='bar', figsize=(10,6))
plt.title('Classification Report Metrics by Class')
plt.ylabel('Score')
plt.xlabel('Classes')
plt.ylim(0,1)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Define hyperparameter grid
param_grid = {
    "learning_rate": [0.01, 0.1],
    "max_depth": [3, 5, 7],
    "n_estimators": [50, 100],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}

best_f1 = -1
best_params = None
best_std = None

# Loop over grid combinations
for lr in param_grid["learning_rate"]:
    for max_depth in param_grid["max_depth"]:
        for n_estimators in param_grid["n_estimators"]:
            for subsample in param_grid["subsample"]:
                for colsample_bytree in param_grid["colsample_bytree"]:
                    params = {
                        "learning_rate": lr,
                        "max_depth": max_depth,
                        "n_estimators": n_estimators,
                        "subsample": subsample,
                        "colsample_bytree": colsample_bytree,
                        "random_state": 42
                    }
                    
                    fold_f1s = []
                    # Manual CV loop
                    for fold, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train), 1):
                        X_train_fold = X_train.iloc[train_idx]
                        y_train_fold = y_train[train_idx]
                        X_val_fold   = X_train.iloc[val_idx]
                        y_val_fold   = y_train[val_idx]
                        
                        model = xgb.XGBClassifier(**params)
                        model.fit(
                            X_train_fold,
                            y_train_fold,
                            eval_set=[(X_val_fold, y_val_fold)],
                            verbose=False
                        )
                        
                        preds = model.predict(X_val_fold)
                        fold_f1 = f1_score(y_val_fold, preds, average="macro")
                        fold_f1s.append(fold_f1)
                    
                    mean_f1 = np.mean(fold_f1s)
                    std_f1 = np.std(fold_f1s)
                    print(f"Params: {params}, Mean Macro F1: {mean_f1:.4f}, Std: {std_f1:.4f}")
                    if mean_f1 > best_f1:
                        best_f1 = mean_f1
                        best_std = std_f1
                        best_params = params

print("\nBest Parameters:", best_params)
print("Best Mean Macro F1 Score:", best_f1)
print("Std of Best Mean Macro F1 Score:", best_std)
# Out:
# Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0673, Std: 0.0027
# Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0713, Std: 0.0021
# Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0676, Std: 0.0028
# Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0716, Std: 0.0022
# Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0694, Std: 0.0025
# Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0715, Std: 0.0021
# Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0686, Std: 0.0030
# Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0709, Std: 0.0022
# Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0699, Std: 0.0032
# Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0725, Std: 0.0033
# Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0689, Std: 0.0028
# Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0719, Std: 0.0030
# Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0704, Std: 0.0033
# Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0726, Std: 0.0032
# Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0698, Std: 0.0028
# Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0729, Std: 0.0026
# Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0708, Std: 0.0031
# Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0730, Std: 0.0033
# Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0703, Std: 0.0031
# Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0720, Std: 0.0025
# Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0716, Std: 0.0030
# Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0730, Std: 0.0028
# Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0711, Std: 0.0029
# Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0724, Std: 0.0029
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0734, Std: 0.0023
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0740, Std: 0.0026
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0731, Std: 0.0023
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0731, Std: 0.0028
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0773, Std: 0.0052
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0779, Std: 0.0042
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0770, Std: 0.0045
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0776, Std: 0.0049
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0764, Std: 0.0053
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0766, Std: 0.0043
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0755, Std: 0.0043
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0773, Std: 0.0067
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0804, Std: 0.0082
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0805, Std: 0.0088
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0801, Std: 0.0080
# Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0796, Std: 0.0093
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0760, Std: 0.0049
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0797, Std: 0.0087
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0781, Std: 0.0090
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0783, Std: 0.0089
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0860, Std: 0.0097
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0817, Std: 0.0089
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.0813, Std: 0.0098
# Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100, 'subsample': 1.0, 'colsample_bytree': 1.0, 'random_state': 42}, Mean Macro F1: 0.0799, Std: 0.0101
#
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}
# Best Mean Macro F1 Score: 0.08599194768018957
# Std of Best Mean Macro F1 Score: 0.00966402098070452

# %%
param_grid = {
    "learning_rate": [0.1, 0.15, 0.2],
    "max_depth": list(range(3, 16, 3)),  # [3, 6, 9, 12, 15]
    "n_estimators": list(range(50, 401, 50)),  # [50, 100, 150, 200, 250, 300, 350, 400]
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}




best_f1 = -1
best_params = None
best_std = None

# Loop over grid combinations
for lr in param_grid["learning_rate"]:
    for max_depth in param_grid["max_depth"]:
        for n_estimators in param_grid["n_estimators"]:
            for subsample in param_grid["subsample"]:
                for colsample_bytree in param_grid["colsample_bytree"]:
                    params = {
                        "learning_rate": lr,
                        "max_depth": max_depth,
                        "n_estimators": n_estimators,
                        "subsample": subsample,
                        "colsample_bytree": colsample_bytree,
                        "random_state": 42
                    }
                    
                    fold_f1s = []
                    # Manual CV loop
                    for fold, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train), 1):
                        X_train_fold = X_train.iloc[train_idx]
                        y_train_fold = y_train[train_idx]
                        X_val_fold   = X_train.iloc[val_idx]
                        y_val_fold   = y_train[val_idx]
                        
                        model = xgb.XGBClassifier(**params)
                        model.fit(
                            X_train_fold,
                            y_train_fold,
                            eval_set=[(X_val_fold, y_val_fold)],
                            verbose=False
                        )
                        
                        preds = model.predict(X_val_fold)
                        fold_f1 = f1_score(y_val_fold, preds, average="macro")
                        fold_f1s.append(fold_f1)
                    
                    mean_f1 = np.mean(fold_f1s)
                    std_f1 = np.std(fold_f1s)
                    print(f"Params: {params}, Mean Macro F1: {mean_f1:.4f}, Std: {std_f1:.4f}")
                    if mean_f1 > best_f1:
                        best_f1 = mean_f1
                        best_std = std_f1
                        best_params = params

print("\nBest Parameters:", best_params)
print("Best Mean Macro F1 Score:", best_f1)
print("Std of Best Mean Macro F1 Score:", best_std)
# Out:
# Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8, 'colsample_bytree': 0.8, 'random_state': 42}, Mean Macro F1: 0.